# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo[(ufo['Shape_Reported'].fillna('missing').str.contains('OVAL')) & (ufo['State'].str.contains('FL','Fl'))]
# Out:
#                    City Colors_Reported Shape_Reported State              Time
# 212               Tampa             NaN           OVAL    FL    8/1/1952 21:30
# 692         Indialantic             NaN           OVAL    FL  10/15/1961 18:00
# 730               Miami             NaN           OVAL    FL     7/1/1962 0:00
# 993               Miami             NaN           OVAL    FL    6/1/1965 20:00
# 1370          Opa Locka             NaN           OVAL    FL    4/1/1967 13:00
# 1770             Naples             NaN           OVAL    FL    1/4/1969 23:30
# 1925         Lake Wales             NaN           OVAL    FL   1/16/1970 19:00
# 1950         Vero Beach             NaN           OVAL    FL   5/16/1970 17:00
# 1951              Tampa          ORANGE           OVAL    FL    5/18/1970 2:00
# 2056        Lake  Wales             NaN           OVAL    FL  12/21/1970 19:00
# 2246            Roanoke             NaN           OVAL    FL    6/30/1972 3:30
# ...

# %%
ufo['State'].str.contains('FL','Fl')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236    False
# 18237    False
# 18238    False
# 18239    False
# 18240     True
# Name: State, Length: 18241, dtype: bool

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# ### Q1 Change columns names: substitute the blank spaces by _

# %%
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# ### Q2 How many different cities are in the dataset?

# %%
ufo['City'].nunique()
# Out:
# 6476

# %%
ufo.groupby('State')['City'].nunique()
# Out:
# State
# AK     59
# AL    107
# AR    111
# AZ    154
# CA    842
# CO    131
# CT    115
# Ca      1
# DE     24
# FL    299
# Fl      4
# GA    160
# HI     53
# IA     98
# ID     64
# IL    298
# IN    164
# KS     88
# KY    136
# LA    105
# MA    179
# MD    112
# ME    123
# MI    293
# MN    147
# MO    222
# MS     93
# MT     71
# NC    187
# ND     29
# NE     48
# NH     81
# NJ    238
# NM     86
# NV     87
# NY    461
# OH    307
# OK     94
# OR    184
# PA    344
# RI     40
# SC     92
# SD     39
# TN    135
# TX    413
# UT     70
# VA    136
# VT     36
# WA    347
# WI    193
# WV     88
# WY     41
# Name: City, dtype: int64

# %%
ufo.groupby('State')['City'].nunique().sum()
# Out:
# 8029

# %%
ufo[ufo['City'] == 'Springfield']

# %% [markdown]
# ### Q3 How many times has the 2nd most frequent ufo shape been reported?

# %%
ufo['Shape_Reported'].value_counts().reset_index().iloc[1,:]
# Out:
# index             DISK
# Shape_Reported    2122
# Name: 1, dtype: object

# %% [markdown]
# ### Q4 How many triangular shapes reported in CA?

# %%
ufo[(ufo['State'].isin(['CA','Ca'])) & (ufo['Shape_Reported'] == 'TRIANGLE')].shape[0]
# Out:
# 210

# %%
(ufo['Shape_Reported'] == 'TRIANGLE')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236     True
# 18237    False
# 18238    False
# 18239    False
# 18240    False
# Name: Shape_Reported, Length: 18241, dtype: bool

# %%
ufo['State'].unique()
# Out:
# array(['NY', 'NJ', 'CO', 'KS', 'ND', 'CA', 'MI', 'AK', 'OR', 'AL', 'SC',
#        'IA', 'GA', 'TN', 'NE', 'LA', 'KY', 'WV', 'NM', 'UT', 'RI', 'FL',
#        'VA', 'NC', 'TX', 'WA', 'ME', 'IL', 'AZ', 'OH', 'PA', 'MN', 'WI',
#        'MD', 'SD', 'NV', 'ID', 'MO', 'OK', 'IN', 'CT', 'MS', 'AR', 'WY',
#        'MA', 'MT', 'DE', 'NH', 'VT', 'HI', 'Ca', 'Fl'], dtype=object)

# %% [markdown]
# ### Q5 How many RED objects were reported on the West Coast?

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
West_Coast = ['CA','Ca','OR','WA']

# %%
ufo[(ufo['State'].isin(West_Coast)) & (ufo['Colors_Reported'].fillna('missing').str.contains('RED'))].shape[0]
# Out:
# 269

# %%
ufo[(ufo['State'].isin(West_Coast)) & (ufo['Colors_Reported'] == 'RED')].shape[0]
# Out:
# 202

# %%
ufo[ufo['Colors_Reported'].fillna('missing').str.contains('RED')]
# Out:
#               City Colors_Reported Shape_Reported State              Time
# 12          Belton             RED         SPHERE    SC   6/30/1939 20:00
# 19      Bering Sea             RED          OTHER    AK   4/30/1943 23:00
# 36      Portsmouth             RED      FORMATION    VA    7/10/1945 1:30
# 91          Scipio             RED         SPHERE    IN   5/10/1948 19:00
# 120        Roswell             RED            NaN    NM    3/22/1950 0:00
# ...            ...             ...            ...   ...               ...
# 18172     Toomsuba             RED           OVAL    MS   12/23/2000 4:00
# 18177     Chandler             RED          LIGHT    AZ  12/23/2000 22:00
# 18191     Fallston             RED        VARIOUS    MD  12/25/2000 19:15
# 18233    Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
#
# [1076 rows x 5 columns]

# %% [markdown]
# ### Q6 What is the oldest report from Arizona?

# %%
ufo.head(25)
# Out:
#                     City Colors_Reported Shape_Reported State  \
# 0                 Ithaca             NaN       TRIANGLE    NY
# 1            Willingboro             NaN          OTHER    NJ
# 2                Holyoke             NaN           OVAL    CO
# 3                Abilene             NaN           DISK    KS
# 4   New York Worlds Fair             NaN          LIGHT    NY
# 5            Valley City             NaN           DISK    ND
# 6            Crater Lake             NaN         CIRCLE    CA
# 7                   Alma             NaN           DISK    MI
# 8                Eklutna             NaN          CIGAR    AK
# 9                Hubbard             NaN       CYLINDER    OR
# 10               Fontana             NaN          LIGHT    CA
# 11              Waterloo             NaN       FIREBALL    AL
# 12                Belton             RED         SPHERE    SC
# 13                Keokuk             NaN           OVAL    IA
# ...

# %%
ufo[ufo['State'] == 'AZ'].iloc[0,3:5]
# Out:
# State                 AZ
# Time     9/30/1946 20:30
# Name: 48, dtype: object

# %% [markdown]
# ### Q7 Print a table with the cities, colors, and state of the objects with shape LIGHT reported in the 90s.

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.loc[(ufo['Time'].str.contains('199')) & (ufo['Shape_Reported'] == 'LIGHT')],['City','Colors_Reported','State']
# Out:
# (                City Colors_Reported Shape_Reported State              Time
#  6272    Sleepy Creek             NaN          LIGHT    NC    2/5/1990 21:00
#  6273      Plattsburg          YELLOW          LIGHT    NY     2/9/1990 2:30
#  6286           Sitka        RED BLUE          LIGHT    AK   3/15/1990 20:50
#  6289      Janesville             NaN          LIGHT    WI   3/15/1990 22:30
#  6294       Thornwood             NaN          LIGHT    NY   4/15/1990 22:00
#  ...              ...             ...            ...   ...               ...
#  15576  South Berwick             RED          LIGHT    ME   12/27/1999 0:00
#  15581    Lake Shasta             NaN          LIGHT    CA   12/28/1999 2:00
#  15585      Elisabeth             NaN          LIGHT    CO  12/28/1999 22:00
#  15592     Huntington             NaN          LIGHT    WV  12/29/1999 19:20
#  15601       Rockford          ORANGE          LIGHT    IL  12/31/1999 23:30
#
#  [1547 rows x 5 columns],
# ...

# %%
(ufo['Shape_Reported'] == 'LIGHT')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 18236    False
# 18237    False
# 18238    False
# 18239     True
# 18240    False
# Name: Shape_Reported, Length: 18241, dtype: bool

# %% [markdown]
# ### Q8 How many objects have been reported at 8pm?

# %%
ufo[ufo['Time'].str.contains('20:00')].shape[0]
# Out:
# 974

# %% [markdown]
# ### Q9 How many reports were reported during regular school day in Florida?

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo[(ufo['Time'].str[-5:-3].astype(int) >= 8) & (ufo['Time'].str[-5:-3].astype(int) <= 16) & (ufo['State'].isin(['FL','Fl']))]
# Out:
#                     City Colors_Reported Shape_Reported State  \
# 31           North Tampa             NaN       CYLINDER    FL
# 34                Jasper             NaN       FIREBALL    FL
# 51                 Miami             NaN          OTHER    FL
# 191                Miami             NaN          LIGHT    FL
# 601       Cape Canaveral             NaN       FIREBALL    FL
# ...                  ...             ...            ...   ...
# 17777  Panama City Beach             NaN          OTHER    FL
# 17909     Tarpon Springs             NaN       CYLINDER    FL
# 17919            Orlando             NaN         CIRCLE    FL
# 18046     Port St. Lucie             NaN           OVAL    FL
# 18186              Miami             NaN            EGG    FL
#
#                    Time
# 31      7/15/1944 13:00
# 34       6/1/1945 13:30
# 51      4/15/1947 14:00
# 191      6/30/1952 9:00
# 601      6/6/1960 12:00
# ...                 ...
# 17777  10/26/2000 13:48
# ...

# %%
ufo['State'].isin(['FL','Fl'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236    False
# 18237    False
# 18238    False
# 18239    False
# 18240     True
# Name: State, Length: 18241, dtype: bool

# %% [markdown]
# ### Q10 From the objects reported at 11pm, in NY, show the top shapes.

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Time'].str.contains('23:00')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236     True
# 18237     True
# 18238    False
# 18239    False
# 18240    False
# Name: Time, Length: 18241, dtype: bool

# %%
ufo['Shape_Reported'].fillna('missing').sort_values().unique()
# Out:
# array(['CHEVRON', 'CIGAR', 'CIRCLE', 'CONE', 'CRESCENT', 'CROSS',
#        'CYLINDER', 'DELTA', 'DIAMOND', 'DISK', 'DOME', 'EGG', 'FIREBALL',
#        'FLARE', 'FLASH', 'FORMATION', 'HEXAGON', 'LIGHT', 'OTHER', 'OVAL',
#        'PYRAMID', 'RECTANGLE', 'ROUND', 'SPHERE', 'TEARDROP', 'TRIANGLE',
#        'VARIOUS', 'missing'], dtype=object)

# %%
ufo.loc[(ufo['State'] == 'NY') & (ufo['Time'].str.contains('23:00')),'Shape_Reported'].value_counts().head()
# Out:
# CIRCLE      10
# TRIANGLE     7
# LIGHT        6
# DISK         4
# OVAL         4
# Name: Shape_Reported, dtype: int64

# %% [markdown]
# ### Q11 Make a table with the top shape and color reported per state.

# %%
ufo.groupby('State')['Shape_Reported', 'Colors_Reported'].describe().loc[:,[('Shape_Reported', 'top'),('Colors_Reported', 'top')]]
# Out:
# <ipython-input-17-c3225f55ef1c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ufo.groupby('State')['Shape_Reported', 'Colors_Reported'].describe().loc[:,[('Shape_Reported', 'top'),('Colors_Reported', 'top')]]
#       Shape_Reported Colors_Reported
#                  top             top
# State
# AK             LIGHT          ORANGE
# AL              DISK          ORANGE
# AR             LIGHT          ORANGE
# AZ             LIGHT             RED
# CA             LIGHT             RED
# CO             LIGHT             RED
# CT              DISK             RED
# Ca          FIREBALL             NaN
# DE          TRIANGLE           GREEN
# FL             LIGHT             RED
# Fl               NaN          ORANGE
# GA              DISK            BLUE
# HI             LIGHT            BLUE
# IA             LIGHT             RED
# ID             LIGHT           GREEN
# ...

# %% [markdown]
# ### Q12 Make a table with the cities of Oregon and the oldest year reported per city

# %%
ufo.loc[ufo['State'] == 'OR'].drop_duplicates('City').loc[:,['City','Time']]
# Out:
#                          City              Time
# 9                     Hubbard    6/15/1937 0:00
# 105                     Salem   6/30/1949 21:00
# 145                 Stanfield   8/15/1950 14:00
# 265                 Corvallis   5/15/1954 12:00
# 519                Terrebonne  10/25/1958 20:00
# ...                       ...               ...
# 17149                  Elkton   8/10/2000 22:00
# 17299  Trout Creek Recreation   8/26/2000 22:00
# 17301          Goverment Camp   8/26/2000 23:30
# 17411        Steens Mountains   9/14/2000 20:00
# 17958             Brownsville  11/16/2000 23:08
#
# [184 rows x 2 columns]

# %% [markdown]
# ### Q13 Make a table with the city with the most reports starting with each letter.(e.g. From all the cities starting with letter A, B, C,...)

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
City.head()
# Out:
#            index  City
# 0        Seattle   187
# 1  New York City   161
# 2        Phoenix   137
# 3        Houston   108
# 4      Las Vegas   105

# %%
City = ufo['City'].value_counts().reset_index()

# %%
City.loc[ufo['City'].value_counts().reset_index().loc[:,'index'].str[0].drop_duplicates().index].sort_values('index')
# Out:
#                                     index  City
# 9                                  Austin    62
# 43                               Bellevue    34
# 8                                 Chicago    73
# 15                                 Dallas    52
# 71                                El Paso    25
# 64                                 Fresno    26
# 24                                Gilbert    45
# 3                                 Houston   108
# 45                           Indianapolis    34
# 20                           Jacksonville    48
# 35                            Kansas City    38
# 4                               Las Vegas   105
# 10                                  Miami    60
# 1                           New York City   161
# 36                                Orlando    37
# 2                                 Phoenix   137
# 268                                Quincy    10
# 29                                   Reno    42
# 0                                 Seattle   187
# ...

# %%
City = ufo.value_counts(['State','City']).reset_index()

# %%
City.loc[ufo.value_counts(['State','City']).reset_index().loc[:,'City'].str(0).drop_duplicates().index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d881db4c6f17> in <cell line: 1>()
# ----> 1 City.loc[ufo.value_counts(['State','City']).reset_index().loc[:,'City'].str(0).drop_duplicates().index]
#
# TypeError: 'StringMethods' object is not callable

# %%
ufo.value_counts(['State','City']).reset_index().loc[:,'City'].str(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-1d1bc2cc01cc> in <cell line: 1>()
# ----> 1 ufo.value_counts(['State','City']).reset_index().loc[:,'City'].str(0)
#
# TypeError: 'StringMethods' object is not callable
